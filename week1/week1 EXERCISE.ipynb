# %% [markdown]
# # End of week 1 exercise
#
# To demonstrate your familiarity with OpenAI API, and also Ollama, build a tool that takes a technical question,
# and responds with an explanation. This is a tool that you will be able to use yourself during the course!

# %%
# imports
import os
from dotenv import load_dotenv
from scraper import fetch_website_contents
from IPython.display import Markdown, display
from openai import OpenAI
import asyncio
from playwright.async_api import async_playwright, Playwright

# %%
# constants

MODEL_GPT = 'gpt-4o-mini'
MODEL_LLAMA = 'llama3.2'

# %%
# set up environment
load_dotenv(override=True)
api_key = os.getenv('OPENAI_API_KEY')

# Check the key

if not api_key:
    print("No API key was found - please head over to the troubleshooting notebook in this folder to identify & fix!")
elif not api_key.startswith("sk-proj-"):
    print("An API key was found, but it doesn't start sk-proj-; please check you're using the right key - see troubleshooting notebook")
elif api_key.strip() != api_key:
    print("An API key was found, but it looks like it might have space or tab characters at the start or end - please remove them - see troubleshooting notebook")
else:
    print("API key found and looks good so far!")
# Out:
# API key found and looks good so far!

# %%
system_prompt = """
You are recruiter with 25 years of experience that analyzes job descriptions,
and determine what would make a candidate a good fit. You will be given a job posting in markdown format.
Please respond with all the requirements, skills, and experience that would help a candidate pass
the applicant tracking system (ATS) of the company. 
Note, it's important to ensure that the candidate is not rejected by the ATS.
Respond in markdown. Do not wrap the markdown in a code block - respond just with the markdown.
"""
user_prompt_prefix = """
Here is the content of the job posting,
Provide a list of requirements, skills, and experience that would help a candidate pass 
the applicant tracking system (ATS) of the company.

"""



# Step 1: configure playwright to scrape website
async def invoke_playwright(playwright: Playwright, url: str):
  # browser = playwright.chromium.launch(headless=False)
  browser = playwright.chromium.launch()
  page = browser.new_page()
  page.goto(url)
  page.wait_for_timeout(1000)
  return page

# Step 2: Scrape website with playwright
async def scrape_website(url):
  async with async_playwright() as playwright:
    page = invoke_playwright(playwright, url)
    content = page.content()
    return content

def messages_for(website):
    return [
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_prompt_prefix + website}
    ]

async def main():
  # await scrape_website("https://phg.tbe.taleo.net/phg02/ats/careers/v2/viewRequisition?org=KEYLOGIC&cws=37&rid=2687")
  async with async_playwright() as playwright:
    page = invoke_playwright(playwright, "https://phg.tbe.taleo.net/phg02/ats/careers/v2/viewRequisition?org=KEYLOGIC&cws=37&rid=2687")
    content = page.content()
    return content

# Step 2: Get gpt-4o-mini to do something which I don't know just yet
asyncio.run(main())

# %%
import asyncio
from playwright.async_api import async_playwright


async def main():
    print("Starting main program (loop starts automatically)")
    await asyncio.sleep(1)
    print("Program finished (loop stops and closes automatically)")

    async with async_playwright() as p:
        browser = await p.chromium.launch()
        page = await browser.new_page()
        await page.goto("https://playwright.dev")
        print(await page.title())
        await browser.close()


if __name__ == "__main__":
    asyncio.run(main())
# https://phg.tbe.taleo.net/phg02/ats/careers/v2/viewRequisition?org=KEYLOGIC&cws=37&rid=2687
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[20], line 19
#      15         await browser.close()
#      18 if __name__ == "__main__":
# ---> 19     asyncio.run(main())
#      20 # https://phg.tbe.taleo.net/phg02/ats/careers/v2/viewRequisition?org=KEYLOGIC&cws=37&rid=2687
#
# File ~/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/asyncio/runners.py:191, in run(main, debug, loop_factory)
#     161 """Execute the coroutine and return the result.
#     162
#     163 This function runs the passed coroutine, taking care of
#    (...)    187     asyncio.run(main())
#     188 """
#     189 if events._get_running_loop() is not None:
#     190     # fail fast with short traceback
# --> 191     raise RuntimeError(
#     192         "asyncio.run() cannot be called from a running event loop")
# ...

# %%
# Get gpt-4o-mini to answer, with streaming

# %%
# Get Llama 3.2 to answer
